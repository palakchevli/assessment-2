# %% [markdown]
# Assessment 1: Financial Analysis

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/finance_economics_dataset (1).csv")
df
# Out:
#             Date Stock Index  Open Price  Close Price  Daily High  Daily Low  \
# 0     2000-01-01   Dow Jones     2128.75      2138.48     2143.70    2100.55
# 1     2000-01-02     S&P 500     2046.82      2036.18     2082.83    2009.53
# 2     2000-01-03   Dow Jones     1987.92      1985.26     2022.28    1978.37
# 3     2000-01-04   Dow Jones     4625.02      4660.47     4665.26    4595.46
# 4     2000-01-05     S&P 500     1998.18      1982.18     2044.31    1966.44
# ...          ...         ...         ...          ...         ...        ...
# 2995  2008-03-14   Dow Jones     1273.76      1235.44     1317.28    1192.34
# 2996  2008-03-15     S&P 500     4589.59      4566.91     4607.56    4545.69
# 2997  2008-03-16     S&P 500     1477.52      1448.47     1523.86    1402.69
# 2998  2008-03-17      NASDAQ     2311.37      2306.90     2346.30    2282.00
# 2999  2008-03-18      NASDAQ     4262.98      4303.82     4316.68    4243.04
#
# ...

# %% [markdown]
# 1. What is the shape of the dataset?

# %%
df1=df.shape
df1
# Out:
# (3000, 24)

# %% [markdown]
# 2. What are the column names and their data types?

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Date                                   3000 non-null   object
#  1   Stock Index                            3000 non-null   object
#  2   Open Price                             3000 non-null   float64
#  3   Close Price                            3000 non-null   float64
#  4   Daily High                             3000 non-null   float64
#  5   Daily Low                              3000 non-null   float64
#  6   Trading Volume                         3000 non-null   int64
#  7   GDP Growth (%)                         3000 non-null   float64
#  8   Inflation Rate (%)                     3000 non-null   float64
#  9   Unemployment Rate (%)                  3000 non-null   float64
# ...

# %% [markdown]
# 3. How many unique stock indices are there?

# %%
df1=df["Stock Index"].nunique()
print(df1)
# Out:
# 3

# %% [markdown]
# 4. What is the date range of the dataset?

# %%
df1=df["Date"].min(), df["Date"].max()
print(df1)
# Out:
# ('2000-01-01', '2008-03-18')

# %% [markdown]
# 5. Are there any missing values?

# %%
df1=df.isnull().sum()
print(df1)
# Out:
# Date                                     0
# Stock Index                              0
# Open Price                               0
# Close Price                              0
# Daily High                               0
# Daily Low                                0
# Trading Volume                           0
# GDP Growth (%)                           0
# Inflation Rate (%)                       0
# Unemployment Rate (%)                    0
# Interest Rate (%)                        0
# Consumer Confidence Index                0
# Government Debt (Billion USD)            0
# Corporate Profits (Billion USD)          0
# Forex USD/EUR                            0
# Forex USD/JPY                            0
# Crude Oil Price (USD per Barrel)         0
# Gold Price (USD per Ounce)               0
# Real Estate Index                        0
# Retail Sales (Billion USD)               0
# Bankruptcy Rate (%)                      0
# Mergers & Acquisitions Deals             0
# ...

# %% [markdown]
# 6. Are there negative values in columns that should be non-negative?

# %%
df1=(df["GDP Growth (%)"] < 0).any()
print(df1)
# Out:
# True

# %% [markdown]
# 7. What is the summary of GDP Growth (%)?

# %%
df1=df["GDP Growth (%)"].describe()
print(df1)
# Out:
# count    3000.000000
# mean        2.608903
# std         4.287337
# min        -5.000000
# 25%        -1.012500
# 50%         2.725000
# 75%         6.242500
# max        10.000000
# Name: GDP Growth (%), dtype: float64

# %% [markdown]
# 8. Are there rows with zero or near-zero trading volume?

# %%
df1=(df["Trading Volume"] <= 1).sum()
df1
# Out:
# np.int64(0)

# %% [markdown]
# 9. Are there any duplicate rows?

# %%
df1=df[df.duplicated()]
print(df1)
# Out:
# Empty DataFrame
# Columns: [Date, Stock Index, Open Price, Close Price, Daily High, Daily Low, Trading Volume, GDP Growth (%), Inflation Rate (%), Unemployment Rate (%), Interest Rate (%), Consumer Confidence Index, Government Debt (Billion USD), Corporate Profits (Billion USD), Forex USD/EUR, Forex USD/JPY, Crude Oil Price (USD per Barrel), Gold Price (USD per Ounce), Real Estate Index, Retail Sales (Billion USD), Bankruptcy Rate (%), Mergers & Acquisitions Deals, Venture Capital Funding (Billion USD), Consumer Spending (Billion USD)]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# 10. Are there outliers in GDP, Gold, or Oil prices?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(data=df[['GDP Growth (%)', 'Gold Price (USD per Ounce)', 'Crude Oil Price (USD per Barrel)']])
plt.title("Boxplot for GDP, Gold, and Oil Prices")
plt.show()

# %% [markdown]
# 11. What is the summary of Inflation Rate (%)?

# %%
df1=df["Inflation Rate (%)"].describe()
print(df1)
# Out:
# count    3000.000000
# mean        5.096830
# std         2.910513
# min         0.010000
# 25%         2.607500
# 50%         5.110000
# 75%         7.600000
# max        10.000000
# Name: Inflation Rate (%), dtype: float64

# %% [markdown]
# 12. What is the average unemployment rate?

# %%
df1=df["Unemployment Rate (%)"].mean()
print(df1)
# Out:
# 8.663786666666667

# %% [markdown]
# 13. Which index has the highest trading volume?

# %%
df1=df.groupby("Stock Index")["Trading Volume"].max()
df1
# Out:
# Stock Index
# Dow Jones    999720907
# NASDAQ       999789343
# S&P 500      999977078
# Name: Trading Volume, dtype: int64

# %% [markdown]
# 14. How many stock records are from each index?

# %%
df1=df["Stock Index"].value_counts()
df1
# Out:
# Stock Index
# S&P 500      1036
# NASDAQ       1007
# Dow Jones     957
# Name: count, dtype: int64

# %% [markdown]
# 15. What is the correlation between inflation and interest rate?

# %%
df1=df[["Inflation Rate (%)","Interest Rate (%)"]].corr()
df1
# Out:
#                     Inflation Rate (%)  Interest Rate (%)
# Inflation Rate (%)            1.000000           0.005733
# Interest Rate (%)             0.005733           1.000000

# %% [markdown]
# 16. What is the average Consumer Confidence Index?

# %%
df1=df["Consumer Confidence Index"].mean()
df1
# Out:
# np.float64(85.036)

# %% [markdown]
# 17. Which column has the highest standard deviation?

# %%
df.std().idxmax()

# %% [markdown]
# 18. What is the highest gold price recorded?

# %%
df1=df["Gold Price (USD per Ounce)"].max()
df1
# Out:
# 2499.66

# %% [markdown]
# 19. Which date had the highest crude oil price?

# %%
df1=df.loc[df["Crude Oil Price (USD per Barrel)"].idxmax(), ["Date","Crude Oil Price (USD per Barrel)"]]
df1
# Out:
# Date                                2001-11-22
# Crude Oil Price (USD per Barrel)        149.87
# Name: 691, dtype: object

# %% [markdown]
# 20. What is the average corporate profit?

# %%
df1=df["Corporate Profits (Billion USD)"].mean()
df1
# Out:
# np.float64(2553.7563333333333)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. What percentage of the dataset shows negative GDP growth?

# %%
neg_gdp_pct = (df["GDP Growth (%)"] < 0).mean() * 100
print(round(neg_gdp_pct, 2), "%")
# Out:
# 31.57 %

# %% [markdown]
# 2. Does high inflation correspond to higher interest rates?

# %%
df1=df[["Interest Rate (%)","Inflation Rate (%)"]].corr().iloc[0,1]
df1
# Out:
# np.float64(0.005732927235576208)

# %% [markdown]
# 3. Is there a relationship between unemployment and consumer spending?

# %%
df1=df[["Unemployment Rate (%)","Consumer Confidence Index"]].corr().iloc[0,1]
df1
# Out:
# np.float64(0.011464223721173108)

# %% [markdown]
# 4. Do higher corporate profits align with higher consumer confidence?

# %%
df1=df[["Corporate Profits (Billion USD)","Consumer Confidence Index"]].corr().iloc[0,1]
df1
# Out:
# np.float64(0.018008055888269477)

# %% [markdown]
# 5. What’s the trend of crude oil prices over time?

# %%
df.plot(x="Date", y="Crude Oil Price (USD per Barrel)", title="Crude Oil Price Trend")
# Out:
# <Axes: title={'center': 'Crude Oil Price Trend'}, xlabel='Date'>

# %% [markdown]
# 6. Are gold prices inversely related to stock performance?

# %%
df1=df[["Gold Price (USD per Ounce)","Close Price"]].corr().iloc[0,1]
df1
# Out:
# np.float64(-0.014543960422329376)

# %% [markdown]
# 7. Does government debt impact consumer confidence?

# %%
df1=df[["Government Debt (Billion USD)","Consumer Confidence Index"]].corr().iloc[0,1]
df1
# Out:
# np.float64(-0.03637006085824999)

# %% [markdown]
# 8. How do mergers & acquisitions (M&A) activity correlate with stock index closing prices?

# %%
df1=df[["Mergers & Acquisitions Deals","Close Price"]].corr().iloc[0,1]
df1
# Out:
# np.float64(0.0026371007894389997)

# %% [markdown]
# 9. Is retail sales growth associated with GDP growth?

# %%
df[["Retail Sales (Billion USD)","GDP Growth (%)"]].corr().iloc[0,1]
# Out:
# np.float64(-0.01428761144571984)

# %% [markdown]
# 10. Is stock market performance linked to consumer spending?

# %%
df[["Close Price","Consumer Confidence Index"]].corr().iloc[0,1]
# Out:
# np.float64(0.013481851433761256)

# %% [markdown]
# 11. Which stock index had the highest average closing price?

# %%
df.groupby("Stock Index")["Close Price"].mean().idxmax()
# Out:
# 'Dow Jones'

# %% [markdown]
# 12. What is the relationship between interest rate and unemployment?

# %%
df[["Interest Rate (%)","Unemployment Rate (%)"]].corr().iloc[0,1]
# Out:
# np.float64(0.018004072130972725)

# %% [markdown]
# 13. Do lower consumer confidence values coincide with higher bankruptcy rates?

# %%
df[["Consumer Confidence Index","Bankruptcy Rate (%)"]].corr().iloc[0,1]
# Out:
# np.float64(-0.01631304347909405)

# %% [markdown]
# 14. Which indicator has the highest correlation with stock close price?

# %%
corrs = df.corr(numeric_only=True)["Close Price"].drop("Close Price").sort_values(ascending=False)
corrs.index[0], "=", corrs.iloc[0]
# Out:
# ('Daily High', '=', np.float64(0.9998208131253348))

# %% [markdown]
# 15. Are unemployment rates lower when corporate profits are high?

# %%
df[["Corporate Profits (Billion USD)","Unemployment Rate (%)"]].corr().iloc[0,1]
# Out:
# np.float64(0.008292414188235592)

# %% [markdown]
# Assessment 2: Retail Sales Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Retail Data.csv")
df
# Out:
#      Order No  Order Date           Customer Name  \
# 0      4293-1  02-09-2014        Vivek Sundaresam
# 1      5001-1  24-10-2015          Shahid Hopkins
# 2      5004-1  13-03-2014           Dennis Pardue
# 3      5009-1  18-02-2013              Sean Wendt
# 4      5010-1  13-09-2014  Christina Vanderzanden
# ...       ...         ...                     ...
# 4995   6831-1  02-11-2016           Roland Murray
# 4996   6847-1  16-12-2015          Patrick OBrill
# 4997   6922-1  28-09-2016            Troy Staebel
# 4998   6939-1  18-06-2016             Shaun Weien
# 4999   6980-1  12-08-2015          Nora Pelletier
#
#                                   Address       City State   Customer Type  \
# 0          152 Bunnerong Road,Eastgardens     Sydney   NSW  Small Business
# 1           438 Victoria Avenue,Chatswood     Sydney   NSW       Corporate
# 2                412 Brunswick St,Fitzroy  Melbourne   VIC        Consumer
# ...

# %% [markdown]
# 1. View the structure of the dataset (columns, types, missing values).

# %%
df.info()

df.isna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order No           5000 non-null   object
#  1   Order Date         5000 non-null   object
#  2   Customer Name      5000 non-null   object
#  3   Address            4999 non-null   object
#  4   City               5000 non-null   object
#  5   State              5000 non-null   object
#  6   Customer Type      5000 non-null   object
#  7   Account Manager    5000 non-null   object
#  8   Order Priority     5000 non-null   object
#  9   Product Name       5000 non-null   object
#  10  Product Category   5000 non-null   object
#  11  Product Container  5000 non-null   object
#  12  Ship Mode          5000 non-null   object
#  13  Ship Date          5000 non-null   object
#  14  Cost Price         5000 non-null   object
#  15  Retail Price       5000 non-null   object
# ...

# %% [markdown]
# 2. What is the shape (rows, columns) of the dataset?

# %%
df.shape
# Out:
# (5000, 24)

# %% [markdown]
# 3. Are there any duplicate records?\

# %%
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# 4. Are there any missing or corrupted entries in Ship Date, Order Date, or numeric
# columns?

# %%
df1=df.select_dtypes(include=np.number).isna()
df1=df[['Order Date','Ship Date']].isna()
df1
# Out:
#       Order Date  Ship Date
# 0          False      False
# 1          False      False
# 2          False      False
# 3          False      False
# 4          False      False
# ...          ...        ...
# 4995       False      False
# 4996       False      False
# 4997       False      False
# 4998       False      False
# 4999       False      False
#
# [5000 rows x 2 columns]

# %% [markdown]
# 5. Convert Order Date and Ship Date to datetime

# %%
df1=df['Order Date'] = pd.to_datetime(df['Order Date'])
df2=df['Ship Date'] = pd.to_datetime(df['Ship Date'])
print(df1,df2)
# Out:
# 0      2014-02-09
# 1             NaT
# 2             NaT
# 3             NaT
# 4             NaT
#           ...
# 4995   2016-02-11
# 4996          NaT
# 4997          NaT
# 4998          NaT
# 4999   2015-12-08
# Name: Order Date, Length: 5000, dtype: datetime64[ns] 0      2014-04-09
# 1             NaT
# 2             NaT
# 3             NaT
# 4             NaT
#           ...
# 4995   2016-06-11
# 4996          NaT
# 4997          NaT
# 4998          NaT
# 4999          NaT
# Name: Ship Date, Length: 5000, dtype: datetime64[ns]

# %% [markdown]
# 6. Check for future or inconsistent shipping dates

# %%
df1=df[df['Ship Date'] > pd.Timestamp.today()]
df[df['Ship Date'] < df['Order Date']]
# Out:
#      Order No Order Date      Customer Name  \
# 204    5106-1 2014-04-09        Cyma Kinney
# 764    5274-1 2014-07-10      Cindy Chapman
# 765    5274-1 2014-06-10       Eric Barreto
# 863    5292-1 2014-04-10       Eric Barreto
# 1292   5396-1 2014-12-02     Julie Prescott
# 1322   5403-1 2013-09-08     Nancy Lomonaco
# 1421   5430-1 2015-04-12    Cari Schnelling
# 1513   5457-1 2014-03-04        Tom Stivers
# 1514   5457-1 2014-03-04        Tom Stivers
# 1594   5479-1 2015-03-03     Anne McFarland
# 1963   5603-1 2014-09-08      Kean Takahito
# 2057   5635-1 2015-03-02        Tom Stivers
# 2098   5646-1 2015-03-02        Tom Stivers
# 2316   5722-1 2014-12-08      Dave Hallsten
# 2450   5781-1 2015-03-02        Tom Stivers
# 2761   5907-1 2015-11-09   Katherine Ducich
# 2841   5934-1 2015-03-02        Tom Stivers
# 2926   5949-1 2015-03-03     Anne McFarland
# 3240   6076-1 2016-08-11   Victoria Pisteka
# 3325   6111-1 2016-03-02        Tom Stivers
# ...

# %% [markdown]
# 8. What are the unique values in Customer Type and Order Priority?

# %%
df1=df['Customer Type'].unique()
df1=df['Order Priority'].unique()
df1
# Out:
# array(['Critical', 'Medium', 'Not Specified', 'Low', 'High'], dtype=object)

# %% [markdown]
# 9. What are the most common shipping modes?

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       4236
# Express Air        647
# Delivery Truck     117
# Name: count, dtype: int64

# %% [markdown]
# 10. Which cities have the highest number of orders?

# %%
df['City'].value_counts().head(10).reset_index()
# Out:
#         City  count
# 0     Sydney   3584
# 1  Melbourne   1416

# %% [markdown]
# 11. What’s the range of order quantities and prices?

# %%
df['Order Quantity'].min(), df['Order Quantity'].max()
df['Cost Price'].min(), df['Cost Price'].max()
# Out:
# ('$0.24', '$99.39')

# %% [markdown]
# 12. Create a new column for shipping duration.

# %%
df['Ship_Duration'] = (df['Ship Date'] - df['Order Date']).dt.days
df['Ship_Duration'].describe()
# Out:
# count    1537.000000
# mean       50.469746
# std        45.734435
# min      -335.000000
# 25%        30.000000
# 50%        59.000000
# 75%        61.000000
# max       394.000000
# Name: Ship_Duration, dtype: float64

# %% [markdown]
# 13. Are there any orders with zero or negative total or quantity?

# %%
df['Order Quantity'] = pd.to_numeric(df['Order Quantity'], errors='coerce')
df['Total'] = pd.to_numeric(df['Total'], errors='coerce')

df[(df['Order Quantity'] < 0) | (df['Total'] < 0)]
# Out:
# Empty DataFrame
# Columns: [Order No, Order Date, Customer Name, Address, City, State, Customer Type, Account Manager, Order Priority, Product Name, Product Category, Product Container, Ship Mode, Ship Date, Cost Price, Retail Price, Profit Margin, Order Quantity, Sub Total, Discount %, Discount $, Order Total, Shipping Cost, Total, Ship_Duration]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# 14. Are all discount percentages matching discount dollar amounts?

# %%
if 'Discount' in df and 'Discount Amount' in df:
    expected = df['Sales'] * df['Discount']
    mismatches = (df['Discount Amount'] - expected).abs() > 0.5
    print(mismatches.sum())
print(mismatches.sum())

# %% [markdown]
# 15. Check for mismatches in total calculation’

# %% [markdown]
# 16. Identify top 5 products by order quantity.

# %%
df1=df.groupby('Product Name')['Order Quantity'].sum().head(5).reset_index()
df1
# Out:
#                                   Product Name  Order Quantity
# 0  "Adams ""While You Were Out"" Message Pads"            51.0
# 1                   "Addiss Metal Binder Clips            12.0
# 2                   1 Stacking Storage Drawers            33.0
# 3                      1-, Tonkins Steel Grame            29.0
# 4                     10 Colored Short Pencils             5.0

# %% [markdown]
# 17. Which Account Manager handled the most revenue?

# %%
if 'Account Manager' in df:
    print(df.groupby('Account Manager')['Cost Price'].sum().head(1))
# Out:
# Account Manager
# Aanya Zhang    $156.50$10.07$0.93$1.09$1.94$2.45$3.52$5.33$2....
# Name: Cost Price, dtype: object

# %% [markdown]
# 18. What is the average shipping cost by mode?

# %%
df['Shipping Cost'] = df['Shipping Cost'].replace('[\$,]', '', regex=True).astype(float)
df1=df.groupby('Ship Mode')['Shipping Cost'].mean().reset_index()
df1
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-873944847.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df['Shipping Cost'] = df['Shipping Cost'].replace('[\$,]', '', regex=True).astype(float)
#         Ship Mode  Shipping Cost
# 0  Delivery Truck       5.270085
# 1     Express Air       5.247311
# 2     Regular Air       5.503553

# %% [markdown]
# 19. Find the most profitable product.

# %%
df.groupby('Product Name')['Profit Margin'].sum().head(1).reset_index()
# Out:
#                                   Product Name    Profit Margin
# 0  "Adams ""While You Were Out"" Message Pads"  $1.26$1.26$1.26

# %% [markdown]
# 20. Find the most profitable product

# %%
df.groupby('Product Name')['Profit Margin'].sum().head(1).reset_index()
# Out:
#                                   Product Name    Profit Margin
# 0  "Adams ""While You Were Out"" Message Pads"  $1.26$1.26$1.26
